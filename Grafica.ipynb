# %% [markdown]
# <a href="https://colab.research.google.com/github/VictorLC28/Investigaci-n-de-Operaciones-I/blob/main/Grafica.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %%
def f(x):
  return np.exp(x)

# %%
x=np.linspace(-5,5,100)

# %%
plt.plot(x,f(x),color="purple")
plt.title("gráfica")
plt.xlabel("X")
plt.ylabel("Y")
# Out:
# Text(0, 0.5, 'Y')
